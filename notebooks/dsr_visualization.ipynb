# %% [markdown]
# # 深度符号回归可视化
#
# ## DSR 结构
#
# Deep Symbolic Regression, DSR (深度符号回归)
#
# ### 网络结构
#
# 建立一个循环神经网络
#
# 输入层： 前一个时刻生成的数学符号（或初始起始符）
#
# 隐藏层： 多层 LSTM
#
# 输出层: 各符号的概率分布 Softmax 函数
#
#
#
# ## 奖励函数
#
# $$
# R(\tau) = \frac{1}{1 + \text{Error} + \lambda \cdot \text{Complexity}}
# $$
